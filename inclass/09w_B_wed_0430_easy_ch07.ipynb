# %% [markdown]
# <a href="https://colab.research.google.com/github/kimham1285/2025-1-myclass-BDA/blob/main/inclass/09w_B_wed_0430_easy_ch07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'sex'   : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})
# %config InlineBackend.figure_format = 'retina'

# %%
df['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(subset = ['score'])
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss = df.dropna(subset = ['score'])
df_nomiss['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df.dropna(subset = [2], axis = 1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %%
df.dropna(subset = [3], axis = 1)
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna()
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df_nomiss = df.dropna(subset = ['score', 'sex'])
df_nomiss
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df_nomiss2 = df.dropna()
df_nomiss2
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score'].mean()
# Out:
# np.float64(4.0)

# %%
df['score'].sum()
# Out:
# np.float64(16.0)

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score  = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman', np.NaN],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip', np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT, pd.NaT]})
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-5fdaf20c5b9f> in <cell line: 0>()
# ----> 1 df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman', np.NaN],
#       2                    "toy": [np.nan, 'Batmobile', 'Bullwhip', np.nan],
#       3                    "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT, pd.NaT]})
#       4 df
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     395
#     396         if attr in __expired_attributes__:
# --> 397             raise AttributeError(
#     398                 f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     399                 f"{__expired_attributes__[attr]}"
#
# AttributeError: `np.NaN` was removed in the NumPy 2.0 release. Use `np.nan` instead.

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.dropna()
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.dropna(axis='columns')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(how='all')
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(how='any')
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.dropna(thresh=2)
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.dropna(thresh=1)
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(thresh=3)
# Out:
# Empty DataFrame
# Columns: [sex, score]
# Index: []

# %%
df.dropna(thresh=1, how='any')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-8d0f789be0c3> in <cell line: 0>()
# ----> 1 df.dropna(thresh=1, how='any')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6644         """
#    6645         if (how is not lib.no_default) and (thresh is not lib.no_default):
# -> 6646             raise TypeError(
#    6647                 "You cannot set both the how and thresh arguments at the same time."
#    6648             )
#
# TypeError: You cannot set both the how and thresh arguments at the same time.

# %%
df.dropna(subset=['name', 'toy'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-76a072265aaa> in <cell line: 0>()
# ----> 1 df.dropna(subset=['name', 'toy'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#
# KeyError: ['name', 'toy']

# %%
df.dropna(subset=['toy'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-94937bfd2d0a> in <cell line: 0>()
# ----> 1 df.dropna(subset=['toy'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#
# KeyError: ['toy']

# %%
df.dropna(subset='toy')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-777e7e638e11> in <cell line: 0>()
# ----> 1 df.dropna(subset='toy')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#
# KeyError: ['toy']

# %%
df1 = pd.DataFrame(index = ['row1', 'row2', 'row3'])
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [row1, row2, row3]

# %%
df1.empty
# Out:
# False

# %%
df1 = pd.DataFrame(columns=['col1','col2','col3'])
df1
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3]
# Index: []

# %%
df1.empty
# Out:
# False

# %%
df1 = pd.DataFrame(index = ['row1', 'row2', 'row3'],
                   columns=['col1', 'col2', 'col3'])
df1
# Out:
#      col1 col2 col3
# row1  NaN  NaN  NaN
# row2  NaN  NaN  NaN
# row3  NaN  NaN  NaN

# %%
df1.empty
# Out:
# False

# %%
df1 = pd.DataFrame(np.nan,
                  index = ['row1', 'row2', 'row3'],
                  columns=['col1','col2','col3'])
df1
# Out:
#       col1  col2  col3
# row1   NaN   NaN   NaN
# row2   NaN   NaN   NaN
# row3   NaN   NaN   NaN

# %%
df1.empty
# Out:
# True

# %% [markdown]
# 빈 프레임데이터 확인 방법 df.empty

# %%
df1 = pd.DataFrame(index = ['row1', 'row2', 'row3'])
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [row1, row2, row3]

# %%
df1.empty
# Out:
# True

# %%
df1 = pd.DataFrame(columns=['col1','col2','col3'])
df1
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3]
# Index: []

# %%
df1.empty
# Out:
# False

# %%
df1 = pd.DataFrame(index = ['row1', 'row2', 'row3'],
                   columns=['col1', 'col2', 'col3'])
df1
# Out:
#      col1 col2 col3
# row1  NaN  NaN  NaN
# row2  NaN  NaN  NaN
# row3  NaN  NaN  NaN

# %%
df1.empty
# Out:
# False

# %%
df1 = pd.DataFrame(np.nan,
                  index = ['row1', 'row2', 'row3'],
                  columns=['col1','col2','col3'])
df1
# Out:
#       col1  col2  col3
# row1   NaN   NaN   NaN
# row2   NaN   NaN   NaN
# row3   NaN   NaN   NaN

# %%
df1.empty
# Out:
# False

# %%
df1 = pd.DataFrame(2,
                  index = ['row1', 'row2', 'row3'],
                  columns=['col1','col2','col3'])
df1
# Out:
#       col1  col2  col3
# row1     2     2     2
# row2     2     2     2
# row3     2     2     2

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
exam = pd.read_csv('data/exam.csv')
exam.loc[[2, 7, 14], ['math']] = np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']]
# Out:
#      math
# 2   100.0
# 7   100.0
# 14  100.0

# %%
exam.loc[[2, 7, 14], 'math']
# Out:
# 2     100.0
# 7     100.0
# 14    100.0
# Name: math, dtype: float64

# %%
round(exam['math'].mean(), 2)
# Out:
# np.float64(61.95)

# %%
import numpy as np
np.set_printoptions(precision=1)
np.array([np.pi])
# Out:
# array([3.1])

# %%
np.set_printoptions(precision=1, suppress = False)
np.array([0.0000001])
# Out:
# array([1.e-07])

# %%
np.set_printoptions(precision=1, suppress = True)
np.array([0.0000001])
# Out:
# array([0.])

# %%
round(np.pi, 2)
# Out:
# 3.14

# %%
exam['math'] = exam['math'].fillna(100)
exam
# Out:
#     id  nclass   math  english  science
# 0    1       1   50.0       98       50
# 1    2       1   60.0       97       60
# 2    3       1  100.0       86       78
# 3    4       1   30.0       98       58
# 4    5       2   25.0       80       65
# 5    6       2   50.0       89       98
# 6    7       2   80.0       90       45
# 7    8       2  100.0       78       25
# 8    9       3   20.0       98       15
# 9   10       3   50.0       98       45
# 10  11       3   65.0       65       65
# 11  12       3   45.0       85       32
# 12  13       4   46.0       98       65
# 13  14       4   48.0       87       12
# 14  15       4  100.0       56       78
# 15  16       4   58.0       98       65
# 16  17       5   65.0       68       98
# 17  18       5   80.0       78       90
# 18  19       5   89.0       68       87
# 19  20       5   78.0       83       58

# %%
exam = pd.read_csv('data/exam.csv')
exam.loc[[2, 7, 14], ['math']] = np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
pd.set_option('display.precision', 2)
exam['math'] = exam['math'].fillna(exam['math'].mean())
exam
# Out:
#     id  nclass   math  english  science
# 0    1       1  50.00       98       50
# 1    2       1  60.00       97       60
# 2    3       1  55.24       86       78
# 3    4       1  30.00       98       58
# 4    5       2  25.00       80       65
# 5    6       2  50.00       89       98
# 6    7       2  80.00       90       45
# 7    8       2  55.24       78       25
# 8    9       3  20.00       98       15
# 9   10       3  50.00       98       45
# 10  11       3  65.00       65       65
# 11  12       3  45.00       85       32
# 12  13       4  46.00       98       65
# 13  14       4  48.00       87       12
# 14  15       4  55.24       56       78
# 15  16       4  58.00       98       65
# 16  17       5  65.00       68       98
# 17  18       5  80.00       78       90
# 18  19       5  89.00       68       87
# 19  20       5  78.00       83       58

# %%
exam['math'].isna().sum()
# Out:
# np.int64(0)

# %%
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_index()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['score'].value_counts()
# Out:
# score
# 4    2
# 5    1
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
df['score'].value_counts().sort_index()
# Out:
# score
# 2    1
# 3    1
# 4    2
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
df['score'] = np.where(df['score'] > 5, np.nan, df['score'])
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
df.dropna(subset = ['sex', 'score']).groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df = pd.DataFrame([1])
df
# Out:
#    0
# 0  1

# %%
df = pd.DataFrame([1, 1, 2, 2])
df
# Out:
#    0
# 0  1
# 1  1
# 2  2
# 3  2

# %%
df = pd.DataFrame([[1, 1, 2, 2]])
df
# Out:
#    0  1  2  3
# 0  1  1  2  2

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 10, np.nan)
df
# Out:
#    x1    x2
# 0   1  10.0
# 1   1  10.0
# 2   2   NaN
# 3   2   NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', None)
df
# Out:
#    x1    x2
# 0   1     a
# 1   1     a
# 2   2  None
# 3   2  None

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-200-73b614d02610> in <cell line: 0>()
# ----> 1 df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'x1'

# %%
df['x2'] = df['x2'].replace('etc', np.nan)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-55b26a6c360a> in <cell line: 0>()
# ----> 1 df['x2'] = df['x2'].replace('etc', np.nan)
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'x2'

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df2 = df.fillna(10)
df2
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 2  10    3.0
# 3   M    4.0
# 4   F   10.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      int64
#  1   x2      4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
type(df2.loc[2, 'x2'])
# Out:
# int

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(10)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 218   volkswagen                   jetta    2.5  2008    5  manual(m5)   f
# 233   volkswagen                  passat    3.6  2008    6    auto(s6)   f
# 90          ford                 mustang    3.8  1999    6  manual(m5)   r
# 82          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 214   volkswagen                   jetta    2.0  1999    4    auto(l4)   f
# 198       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 232   volkswagen                  passat    2.8  1999    6  manual(m5)   f
# 229   volkswagen                  passat    2.0  2008    4    auto(s6)   f
# 47         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 173       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
#
#      cty  hwy fl    category
# 218   21   29  r     compact
# 233   17   26  p     midsize
# 90    18   26  r  subcompact
# 82    13   17  r         suv
# 214   19   26  r     compact
# 198   11   15  r         suv
# 232   18   26  p     midsize
# 229   19   28  p     midsize
# 47    16   23  r     minivan
# 173   15   20  r         suv

# %%
import seaborn as sns
sns.boxplot(data = mpg, y = 'hwy');

# %%
s = pd.Series([1, 2, 3, 4, 5])

# %%
s.quantile([.01, .25, .50, .75, 1])
# Out:
# 0.01    1.04
# 0.25    2.00
# 0.50    3.00
# 0.75    4.00
# 1.00    5.00
# dtype: float64

# %%
s.quantile(.50)
# Out:
# np.float64(3.0)

# %%
s.quantile([.25, .5, .75, 1])
# Out:
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# 1.00    5.0
# dtype: float64

# %%
s2 = pd.Series([1, 2, 4, 5])

# %%
s2.quantile([.25, .5, .75, 1])
# Out:
# 0.25    1.75
# 0.50    3.00
# 0.75    4.25
# 1.00    5.00
# dtype: float64

# %%
pct25, pct50, pct75 = mpg['hwy'].quantile([.25, .5, .75])
pct25
# Out:
# 18.0

# %%
pct50, pct75
# Out:
# (24.0, 27.0)

# %%
iqr = pct75 - pct25
iqr
# Out:
# 9.0

# %%
pct25 - 1.5 * iqr
# Out:
# 4.5

# %%
pct75 + 1.5 * iqr
# Out:
# 40.5

# %%
mpg['hwy'].describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg['hwy'].describe()['25%']
# Out:
# np.float64(18.0)

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
import missingno as msno
msno.matrix(mpg);

# %%
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])

# %%
mpg['hwy'].isna().sum()
# Out:
# np.int64(3)

# %%
dmpg = mpg.dropna(subset = ['hwy'])
len(dmpg)
# Out:
# 231

# %%
dmpg.dropna(subset = ['hwy']).groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       27.73
# r       21.00

# %%
dmpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       27.73
# r       21.00

# %%
len(mpg)
# Out:
# 234

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       28.16
# r       21.00

# %%
mpg[ mpg['hwy'] > 40.5 ]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg.query( 'hwy > 40.5' )
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
pd.isna(df).sum()
df_nomiss = df.dropna(subset = ['score'])
df_nomiss = df.dropna(subset = ['score', 'sex'])

df['sex'].value_counts(sort = False)
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
pct25 = mpg['hwy'].quantile(.25)
pct75 = mpg['hwy'].quantile(.75)
iqr = pct75 - pct25
pct25 - 1.5 * iqr
pct75 + 1.5 * iqr

mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])

# %%
mpg = pd.read_csv('data/mpg.csv')

import seaborn as sns
sns.boxplot(data = mpg, y = 'hwy');
